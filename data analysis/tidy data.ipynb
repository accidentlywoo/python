# %%
import pandas as pd

# %%
pew = pd.read_csv('/Users/scminnoG15/jupyter-note/python/data analysis/tidy-data-master/tidy-data-master/data/pew.txt'
                  ,delimiter='\t')

# %%
pew
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %% [markdown]
# -> 잘못 만든 데이터
#
# 범위를 변경하려면 스키마를 바꿔야 한다.
#
# 이런 형식은 'wide format' -> 사람이 보기 좋은 것
#
# 헬멧님이 이런걸 바꿔줄 기능을 만드셨다.

# %%
pew.melt??

# %%
pew.melt()
# Pandas의 특징
# Out:
#                variable                    value
# 0              religion                 Agnostic
# 1              religion                  Atheist
# 2              religion                 Buddhist
# 3              religion                 Catholic
# 4              religion       Don’t know/refused
# 5              religion         Evangelical Prot
# 6              religion                    Hindu
# 7              religion  Historically Black Prot
# 8              religion        Jehovah's Witness
# 9              religion                   Jewish
# 10             religion            Mainline Prot
# 11             religion                   Mormon
# 12             religion                   Muslim
# 13             religion                 Orthodox
# 14             religion          Other Christian
# 15             religion             Other Faiths
# 16             religion    Other World Religions
# 17             religion             Unaffiliated
# ...

# %%
pew.melt(['religion'])
# Out:
#                     religion            variable  value
# 0                   Agnostic               <$10k     27
# 1                    Atheist               <$10k     12
# 2                   Buddhist               <$10k     27
# 3                   Catholic               <$10k    418
# 4         Don’t know/refused               <$10k     15
# 5           Evangelical Prot               <$10k    575
# 6                      Hindu               <$10k      1
# 7    Historically Black Prot               <$10k    228
# 8          Jehovah's Witness               <$10k     20
# 9                     Jewish               <$10k     19
# 10             Mainline Prot               <$10k    289
# 11                    Mormon               <$10k     29
# 12                    Muslim               <$10k      6
# 13                  Orthodox               <$10k     13
# 14           Other Christian               <$10k      9
# 15              Other Faiths               <$10k     20
# ...

# %% [markdown]
#  -> 'long format' 분석하기 좋은 데이터

# %%
pew.melt(['religion'],var_name='문', value_name='근영')
# Out:
#                     religion                   문    근영
# 0                   Agnostic               <$10k    27
# 1                    Atheist               <$10k    12
# 2                   Buddhist               <$10k    27
# 3                   Catholic               <$10k   418
# 4         Don’t know/refused               <$10k    15
# 5           Evangelical Prot               <$10k   575
# 6                      Hindu               <$10k     1
# 7    Historically Black Prot               <$10k   228
# 8          Jehovah's Witness               <$10k    20
# 9                     Jewish               <$10k    19
# 10             Mainline Prot               <$10k   289
# 11                    Mormon               <$10k    29
# 12                    Muslim               <$10k     6
# 13                  Orthodox               <$10k    13
# 14           Other Christian               <$10k     9
# 15              Other Faiths               <$10k    20
# ...

# %%
# inplace없다 재할당
pew = pew.melt(['religion'])

# %%
pew
# Out:
#                     religion            variable  value
# 0                   Agnostic               <$10k     27
# 1                    Atheist               <$10k     12
# 2                   Buddhist               <$10k     27
# 3                   Catholic               <$10k    418
# 4         Don’t know/refused               <$10k     15
# 5           Evangelical Prot               <$10k    575
# 6                      Hindu               <$10k      1
# 7    Historically Black Prot               <$10k    228
# 8          Jehovah's Witness               <$10k     20
# 9                     Jewish               <$10k     19
# 10             Mainline Prot               <$10k    289
# 11                    Mormon               <$10k     29
# 12                    Muslim               <$10k      6
# 13                  Orthodox               <$10k     13
# 14           Other Christian               <$10k      9
# 15              Other Faiths               <$10k     20
# ...

# %%
pew.describe()
# Out:
#              value
# count   180.000000
# mean    197.533333
# std     326.548693
# min       1.000000
# 25%      18.000000
# 50%      46.000000
# 75%     218.500000
# max    1529.000000

# %%
pew.groupby('variable').mean()
# Out:
#                          value
# variable
# $10-20k             154.500000
# $100-150k           177.611111
# $20-30k             186.500000
# $30-40k             183.444444
# $40-50k             171.388889
# $50-75k             288.055556
# $75-100k            221.666667
# <$10k               107.222222
# >150k               144.888889
# Don't know/refused  340.055556

# %% [markdown]
# long 포맷이 아니면 분석에 사용할 수 없다.
#
# 1. tidy data가 아니면 long data로 바꾸자.

# %%
weather = pd.read_csv('/Users/scminnoG15/jupyter-note/python/data analysis/tidy-data-master/tidy-data-master/data/weather.txt'
                  ,delimiter='\t', na_filter='-')

# %%
weather
# Out:
#              id  year  month element     d1     d2     d3     d4     d5  \
# 0   MX000017004  2010      1    TMAX    NaN    NaN    NaN    NaN    NaN
# 1   MX000017004  2010      1    TMIN    NaN    NaN    NaN    NaN    NaN
# 2   MX000017004  2010      2    TMAX    NaN  273.0  241.0    NaN    NaN
# 3   MX000017004  2010      2    TMIN    NaN  144.0  144.0    NaN    NaN
# 4   MX000017004  2010      3    TMAX    NaN    NaN    NaN    NaN  321.0
# 5   MX000017004  2010      3    TMIN    NaN    NaN    NaN    NaN  142.0
# 6   MX000017004  2010      4    TMAX    NaN    NaN    NaN    NaN    NaN
# 7   MX000017004  2010      4    TMIN    NaN    NaN    NaN    NaN    NaN
# 8   MX000017004  2010      5    TMAX    NaN    NaN    NaN    NaN    NaN
# 9   MX000017004  2010      5    TMIN    NaN    NaN    NaN    NaN    NaN
# 10  MX000017004  2010      6    TMAX    NaN    NaN    NaN    NaN    NaN
# 11  MX000017004  2010      6    TMIN    NaN    NaN    NaN    NaN    NaN
# ...

# %% [markdown]
# melt -> 고정하고 싶은 새끼를 쓴다.

# %%
weather.melt(weather.columns[:4])
# Out:
#               id  year  month element variable  value
# 0    MX000017004  2010      1    TMAX       d1    NaN
# 1    MX000017004  2010      1    TMIN       d1    NaN
# 2    MX000017004  2010      2    TMAX       d1    NaN
# 3    MX000017004  2010      2    TMIN       d1    NaN
# 4    MX000017004  2010      3    TMAX       d1    NaN
# 5    MX000017004  2010      3    TMIN       d1    NaN
# 6    MX000017004  2010      4    TMAX       d1    NaN
# 7    MX000017004  2010      4    TMIN       d1    NaN
# 8    MX000017004  2010      5    TMAX       d1    NaN
# 9    MX000017004  2010      5    TMIN       d1    NaN
# 10   MX000017004  2010      6    TMAX       d1    NaN
# 11   MX000017004  2010      6    TMIN       d1    NaN
# 12   MX000017004  2010      7    TMAX       d1    NaN
# 13   MX000017004  2010      7    TMIN       d1    NaN
# 14   MX000017004  2010      8    TMAX       d1    NaN
# 15   MX000017004  2010      8    TMIN       d1    NaN
# ...

# %%
weather.melt(weather.columns[:4]).dropna()
# Out:
#               id  year  month element variable  value
# 20   MX000017004  2010     12    TMAX       d1  299.0
# 21   MX000017004  2010     12    TMIN       d1  138.0
# 24   MX000017004  2010      2    TMAX       d2  273.0
# 25   MX000017004  2010      2    TMIN       d2  144.0
# 40   MX000017004  2010     11    TMAX       d2  313.0
# 41   MX000017004  2010     11    TMIN       d2  163.0
# 46   MX000017004  2010      2    TMAX       d3  241.0
# 47   MX000017004  2010      2    TMIN       d3  144.0
# 56   MX000017004  2010      7    TMAX       d3  286.0
# 57   MX000017004  2010      7    TMIN       d3  175.0
# 84   MX000017004  2010     11    TMAX       d4  272.0
# 85   MX000017004  2010     11    TMIN       d4  120.0
# 92   MX000017004  2010      3    TMAX       d5  321.0
# 93   MX000017004  2010      3    TMIN       d5  142.0
# 102  MX000017004  2010      8    TMAX       d5  296.0
# 103  MX000017004  2010      8    TMIN       d5  158.0
# ...

# %%
weather = weather.melt(weather.columns[:4],value_name='day').dropna()

# %%
weather
# Out:
#               id  year  month element variable    day
# 20   MX000017004  2010     12    TMAX       d1  299.0
# 21   MX000017004  2010     12    TMIN       d1  138.0
# 24   MX000017004  2010      2    TMAX       d2  273.0
# 25   MX000017004  2010      2    TMIN       d2  144.0
# 40   MX000017004  2010     11    TMAX       d2  313.0
# 41   MX000017004  2010     11    TMIN       d2  163.0
# 46   MX000017004  2010      2    TMAX       d3  241.0
# 47   MX000017004  2010      2    TMIN       d3  144.0
# 56   MX000017004  2010      7    TMAX       d3  286.0
# 57   MX000017004  2010      7    TMIN       d3  175.0
# 84   MX000017004  2010     11    TMAX       d4  272.0
# 85   MX000017004  2010     11    TMIN       d4  120.0
# 92   MX000017004  2010      3    TMAX       d5  321.0
# 93   MX000017004  2010      3    TMIN       d5  142.0
# 102  MX000017004  2010      8    TMAX       d5  296.0
# 103  MX000017004  2010      8    TMIN       d5  158.0
# ...

# %%
weather.describe()
# Out:
#          year      month         day
# count    66.0  66.000000   66.000000
# mean   2010.0   7.212121  219.212121
# std       0.0   3.417220   77.294744
# min    2010.0   1.000000   79.000000
# 25%    2010.0   4.000000  150.000000
# 50%    2010.0   8.000000  211.500000
# 75%    2010.0  10.000000  289.250000
# max    2010.0  12.000000  363.000000

# %%
weather.drop(columns=['id','year'], inplace=True)

# %%
weather
# Out:
#      month element variable    day
# 20      12    TMAX       d1  299.0
# 21      12    TMIN       d1  138.0
# 24       2    TMAX       d2  273.0
# 25       2    TMIN       d2  144.0
# 40      11    TMAX       d2  313.0
# 41      11    TMIN       d2  163.0
# 46       2    TMAX       d3  241.0
# 47       2    TMIN       d3  144.0
# 56       7    TMAX       d3  286.0
# 57       7    TMIN       d3  175.0
# 84      11    TMAX       d4  272.0
# 85      11    TMIN       d4  120.0
# 92       3    TMAX       d5  321.0
# 93       3    TMIN       d5  142.0
# 102      8    TMAX       d5  296.0
# 103      8    TMIN       d5  158.0
# 104     10    TMAX       d5  270.0
# 105     10    TMIN       d5  140.0
# 106     11    TMAX       d5  263.0
# 107     11    TMIN       d5   79.0
# 130     12    TMAX       d6  278.0
# 131     12    TMIN       d6  105.0
# 148     10    TMAX       d7  281.0
# 149     10    TMIN       d7  129.0
# 168      8    TMAX       d8  290.0
# 169      8    TMIN       d8  173.0
# ...

# %%
weather.reset_index(drop=True, inplace=True)

# %%
weather
# Out:
#     month element variable    day
# 0      12    TMAX       d1  299.0
# 1      12    TMIN       d1  138.0
# 2       2    TMAX       d2  273.0
# 3       2    TMIN       d2  144.0
# 4      11    TMAX       d2  313.0
# 5      11    TMIN       d2  163.0
# 6       2    TMAX       d3  241.0
# 7       2    TMIN       d3  144.0
# 8       7    TMAX       d3  286.0
# 9       7    TMIN       d3  175.0
# 10     11    TMAX       d4  272.0
# 11     11    TMIN       d4  120.0
# 12      3    TMAX       d5  321.0
# 13      3    TMIN       d5  142.0
# 14      8    TMAX       d5  296.0
# 15      8    TMIN       d5  158.0
# 16     10    TMAX       d5  270.0
# 17     10    TMIN       d5  140.0
# 18     11    TMAX       d5  263.0
# 19     11    TMIN       d5   79.0
# 20     12    TMAX       d6  278.0
# 21     12    TMIN       d6  105.0
# 22     10    TMAX       d7  281.0
# 23     10    TMIN       d7  129.0
# 24      8    TMAX       d8  290.0
# 25      8    TMIN       d8  173.0
# ...

# %%
weather.day = weather.variable.str.replace('d','')

# %%
weather
# Out:
#     month element variable day
# 0      12    TMAX       d1   1
# 1      12    TMIN       d1   1
# 2       2    TMAX       d2   2
# 3       2    TMIN       d2   2
# 4      11    TMAX       d2   2
# 5      11    TMIN       d2   2
# 6       2    TMAX       d3   3
# 7       2    TMIN       d3   3
# 8       7    TMAX       d3   3
# 9       7    TMIN       d3   3
# 10     11    TMAX       d4   4
# 11     11    TMIN       d4   4
# 12      3    TMAX       d5   5
# 13      3    TMIN       d5   5
# 14      8    TMAX       d5   5
# 15      8    TMIN       d5   5
# 16     10    TMAX       d5   5
# 17     10    TMIN       d5   5
# 18     11    TMAX       d5   5
# 19     11    TMIN       d5   5
# 20     12    TMAX       d6   6
# 21     12    TMIN       d6   6
# 22     10    TMAX       d7   7
# 23     10    TMIN       d7   7
# 24      8    TMAX       d8   8
# 25      8    TMIN       d8   8
# 26      3    TMAX      d10  10
# 27      3    TMIN      d10  10
# 28      2    TMAX      d11  11
# ...

# %%
weather.variable = weather.variable.astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-7c28ba43b711> in <module>
# ----> 1 weather.variable = weather.variable.astype('int64')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# ...

# %%
billboard = pd.read_csv('/Users/scminnoG15/jupyter-note/python/data analysis/tidy-data-master/tidy-data-master/data/billboard.csv'
                       ,date_parser=True)

# %%
billboard
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
billboard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 83 columns):
# year               317 non-null int64
# artist.inverted    317 non-null object
# track              317 non-null object
# time               317 non-null object
# genre              317 non-null object
# date.entered       317 non-null object
# date.peaked        317 non-null object
# x1st.week          317 non-null int64
# x2nd.week          312 non-null float64
# x3rd.week          307 non-null float64
# x4th.week          300 non-null float64
# x5th.week          292 non-null float64
# x6th.week          280 non-null float64
# x7th.week          269 non-null float64
# x8th.week          260 non-null float64
# x9th.week          253 non-null float64
# x10th.week         244 non-null float64
# x11th.week         236 non-null float64
# x12th.week         222 non-null float64
# x13th.week         210 non-null float64
# x14th.week         204 non-null float64
# ...

# %%
pd.wide_to_long(billboard)

# %%
weather = pd.read_csv('/Users/scminnoG15/jupyter-note/python/data analysis/tidy-data-master/tidy-data-master/data/weather.txt'
                  ,delimiter='\t', na_filter='-')

# %%
pd.wide_to_long(weather,'d',['id','year','month','element'],'').dropna()
# Out:
#                                        d
# id          year month element
# MX000017004 2010 1     TMAX    30  278.0
#                        TMIN    30  145.0
#                  2     TMAX    2   273.0
#                                3   241.0
#                                11  297.0
#                                23  299.0
#                        TMIN    2   144.0
#                                3   144.0
#                                11  134.0
#                                23  107.0
#                  3     TMAX    5   321.0
#                                10  345.0
#                                16  311.0
#                        TMIN    5   142.0
#                                10  168.0
#                                16  176.0
#                  4     TMAX    27  363.0
#                        TMIN    27  167.0
#                  5     TMAX    27  332.0
#                        TMIN    27  182.0
#                  6     TMAX    17  280.0
# ...
