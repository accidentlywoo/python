# %%
import pandas as pd

# %%
dust = pd.read_csv('/Users/scminnoG15/jupyter-note/python/data-analysis/micro-kwang.csv'
                 ,engine='python')

# %%
dust
# Out:
#              날짜   미세먼지농도 (㎍/㎥)  결과
# 0    2017-01-10             19  좋음
# 1    2017-01-11             20  좋음
# 2    2017-01-13             29  좋음
# 3    2017-01-14             40  보통
# 4    2017-01-20             20  좋음
# 5    2017-01-21             20  좋음
# 6    2017-01-27             25  좋음
# 7    2017-01-28             40  보통
# 8    2017-01-31             40  보통
# 9    2017-02-01             50  보통
# 10   2017-02-02             10  좋음
# 11   2017-02-03             22  좋음
# 12   2017-02-06             25  좋음
# 13   2017-02-07             27  좋음
# 14   2017-02-08             30  좋음
# 15   2017-02-09             41  보통
# 16   2017-02-10             42  보통
# 17   2017-02-11             19  좋음
# 18   2017-02-14             18  좋음
# 19   2017-02-15             20  좋음
# 20   2017-02-16             22  좋음
# 21   2017-02-17             43  보통
# 22   2017-02-22             43  보통
# 23   2017-02-23             41  보통
# 24   2017-02-24             20  좋음
# 25   2017-02-25             30  좋음
# ...

# %%
dust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 3 columns):
# 날짜               250 non-null object
#  미세먼지농도 (㎍/㎥)    250 non-null int64
# 결과               250 non-null object
# dtypes: int64(1), object(2)
# memory usage: 5.9+ KB

# %%
# 시간 데이터타입 변경하는 쉬운 방법
# yyyy-mm-dd : 국제표준기법
temp = pd.to_datetime(dust['날짜'])

# %%
type(temp)
# Out:
# pandas.core.series.Series

# %%
dust['날짜'] = pd.to_datetime(dust['날짜'])
# -> rangeIndex resample안댐

# %% [markdown]
# resample : 데이트타입은 시간 날짜 간격에따라서 합칠 수 있다.

# %%
dust['날짜'].resample()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-4e691bb393ac> in <module>
# ----> 1 dust['날짜'].resample()
#
# TypeError: resample() missing 1 required positional argument: 'rule'

# %%
# Timestamp vs Series vs DatetimeIndex

dust = dust.set_index('날짜')

# %%
# %matplotlib inline

# %%
dust.plot.line()

# %%
dust
# Out:
#              미세먼지농도 (㎍/㎥)  결과
# 날짜
# 2017-01-10             19  좋음
# 2017-01-11             20  좋음
# 2017-01-13             29  좋음
# 2017-01-14             40  보통
# 2017-01-20             20  좋음
# 2017-01-21             20  좋음
# 2017-01-27             25  좋음
# 2017-01-28             40  보통
# 2017-01-31             40  보통
# 2017-02-01             50  보통
# 2017-02-02             10  좋음
# 2017-02-03             22  좋음
# 2017-02-06             25  좋음
# 2017-02-07             27  좋음
# 2017-02-08             30  좋음
# 2017-02-09             41  보통
# 2017-02-10             42  보통
# 2017-02-11             19  좋음
# 2017-02-14             18  좋음
# 2017-02-15             20  좋음
# 2017-02-16             22  좋음
# 2017-02-17             43  보통
# 2017-02-22             43  보통
# 2017-02-23             41  보통
# 2017-02-24             20  좋음
# 2017-02-25             30  좋음
# 2017-02-26             35  보통
# 2017-02-27             37  보통
# 2017-03-01             38  보통
# 2017-03-02             39  보통
# ...

# %%
dust['2017-03':'2017-06']
# Out:
#              미세먼지농도 (㎍/㎥)  결과
# 날짜
# 2017-03-01             38  보통
# 2017-03-02             39  보통
# 2017-03-03             29  좋음
# 2017-03-06             30  좋음
# 2017-03-07             40  보통
# 2017-03-08             41  보통
# 2017-03-09             20  좋음
# 2017-03-12             21  좋음
# 2017-03-13             22  좋음
# 2017-03-18             23  좋음
# 2017-03-19             30  좋음
# 2017-03-20             24  좋음
# 2017-03-21             25  좋음
# 2017-03-22             25  좋음
# 2017-03-23             30  좋음
# 2017-03-30             30  좋음
# 2017-03-31             30  좋음
# 2017-04-01             30  좋음
# 2017-04-02             24  좋음
# 2017-04-03             40  보통
# 2017-04-04             40  보통
# 2017-04-05             30  좋음
# 2017-04-06             35  보통
# 2017-04-07             35  보통
# 2017-04-08             35  보통
# 2017-04-09             36  보통
# 2017-04-10             20  좋음
# 2017-04-13             31  보통
# 2017-04-14             33  보통
# 2017-04-15             35  보통
# ...

# %%
index = pd.date_range('1/1/2000', periods=9, freq='T')

# %%
series = pd.Series(range(9), index=index)

# %%
series
# Out:
# 2000-01-01 00:00:00    0
# 2000-01-01 00:01:00    1
# 2000-01-01 00:02:00    2
# 2000-01-01 00:03:00    3
# 2000-01-01 00:04:00    4
# 2000-01-01 00:05:00    5
# 2000-01-01 00:06:00    6
# 2000-01-01 00:07:00    7
# 2000-01-01 00:08:00    8
# Freq: T, dtype: int64

# %%
# 집계함수 쓴다. group느낌쓰 난다.
series.resample('3T').sum()
# resample은 datatimeindex 타입에서면 사용할 수 있다.
# Out:
# 2000-01-01 00:00:00     3
# 2000-01-01 00:03:00    12
# 2000-01-01 00:06:00    21
# Freq: 3T, dtype: int64

# %%
dust
# Out:
#              미세먼지농도 (㎍/㎥)  결과
# 날짜
# 2017-01-10             19  좋음
# 2017-01-11             20  좋음
# 2017-01-13             29  좋음
# 2017-01-14             40  보통
# 2017-01-20             20  좋음
# 2017-01-21             20  좋음
# 2017-01-27             25  좋음
# 2017-01-28             40  보통
# 2017-01-31             40  보통
# 2017-02-01             50  보통
# 2017-02-02             10  좋음
# 2017-02-03             22  좋음
# 2017-02-06             25  좋음
# 2017-02-07             27  좋음
# 2017-02-08             30  좋음
# 2017-02-09             41  보통
# 2017-02-10             42  보통
# 2017-02-11             19  좋음
# 2017-02-14             18  좋음
# 2017-02-15             20  좋음
# 2017-02-16             22  좋음
# 2017-02-17             43  보통
# 2017-02-22             43  보통
# 2017-02-23             41  보통
# 2017-02-24             20  좋음
# 2017-02-25             30  좋음
# 2017-02-26             35  보통
# 2017-02-27             37  보통
# 2017-03-01             38  보통
# 2017-03-02             39  보통
# ...

# %% [markdown]
# 시간 - 타겟 : 시계열 분석이 힘들 수 있다.

# %%
dust.resample('3T').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-ec74e54f37d3> in <module>
# ----> 1 dust.resample('3T').sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    8153                      axis=axis, kind=kind, loffset=loffset,
#    8154                      convention=convention,
# -> 8155                      base=base, key=on, level=level)
#    8156         return _maybe_process_deprecations(r,
#    8157                                            how=how,
#
# ~\Anaconda3\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#    1248     """
#    1249     tg = TimeGrouper(**kwds)
# -> 1250     return tg._get_resampler(obj, kind=kind)
#    1251
#    1252
#
# ...

# %% [markdown]
# 시간데이터타입을 numpy기반으로 만들었을 때 효율성이 너무 작아서 Python에서 들고 와따.
#
# https://facebook.github.io/prophet/docs/quick_start.html

# %%
# !pip install fbprophet

# %%
from fbprophet import Prophet
